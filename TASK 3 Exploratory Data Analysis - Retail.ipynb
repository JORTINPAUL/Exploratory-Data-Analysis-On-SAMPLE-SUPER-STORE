# %% [markdown]
# # THE SPARKS FOUNDATION

# %% [markdown]
# # AUTHOR - JORTIN PAUL

# %% [markdown]
# # TASK 3:EXPLORATORY DATA ANALYSIS - RETAIL

# %% [markdown]
# ## DATA SET: SAMPLESUPERSTORE

# %% [markdown]
# ### Problem Statement: Try to find out weak areas where you can work to make more profit

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the Data

# %%
df= pd.read_csv('C:/Users/JORTIN PAUL/Documents/PROJECTS/Sparks Internship/SampleSuperstore.csv')

# %% [markdown]
# ### Understand the Data

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='copper')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### As we don't have any null values in our data set we can move forward for further procedures

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
# To check weather there is any duplicate row in the dataset

df.duplicated().sum()
# Out:
# 17

# %%
df[df.duplicated()].shape
# Out:
# (17, 13)

# %%
# there are 17 duplicate rows , so we need to drop them

df= df.drop_duplicates()

# %%
#After dropping the duplicates
df.shape
# Out:
# (9977, 13)

# %%
# To know about the total sales and the profit generated by the retail store.

print('Sales:',df['Sales'].sum())
print('Profit:',df['Profit'].sum())
# Out:
# Sales: 2296195.5903
# Profit: 286241.4226

# %%
#Deleting the Variable

col=['Postal Code']
df1=df.drop(columns=col,axis=1)

# %% [markdown]
# #### Correlation

# %%
#Correlation Between Variables
df1.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %%
corr = df1.corr()
sns.heatmap(corr,annot=True,cmap='inferno')
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x="Profit",y="Discount",data=df1)
plt.ylim(0,)
# Out:
# (0.0, 2.1845233468663148)

# %%
sns.regplot(x="Profit",y="Sales",data=df1)
plt.ylim(0,)
# Out:
# (0.0, 24339.804639909424)

# %%
sns.regplot(x="Profit",y="Quantity",data=df1)
plt.ylim(0,)
# Out:
# (0.0, 14.852348244300586)

# %% [markdown]
# #### We can see that there is a Positive correlation between Sales & Profit whereas Negative correlation Discount & Profit

# %% [markdown]
# #### Covariance

# %%
# Covariance of columns
df1.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     389028.396022  278.765576  -3.645637  70057.067126
# Quantity     278.765576    4.958001   0.003990     34.565743
# Discount      -3.645637    0.003990   0.042624    -10.632751
# Profit     70057.067126   34.565743 -10.632751  54970.478824

# %% [markdown]
# #### Ship Mode

# %%
df1['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x=df1['Ship Mode']).set_title('SHIP MODE')
# Out:
# Text(0.5, 1.0, 'SHIP MODE')

# %%
sns.pairplot(df1,hue='Ship Mode')

# %% [markdown]
# #### Highest Ship Mode is Standard Class following with Second & FIrst Class

# %% [markdown]
# #### Segment

# %%
df1['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
sns.countplot(x='Segment',data=df1).set_title('SEGMENT')
# Out:
# Text(0.5, 1.0, 'SEGMENT')

# %%
sns.pairplot(df1,hue='Segment')

# %% [markdown]
# #### Highest Segment is Consumer Segment following with Corporate & Home Office

# %% [markdown]
# #### Category

# %%
df1['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category',data=df1).set_title('CATEGORY')
# Out:
# Text(0.5, 1.0, 'CATEGORY')

# %%
sns.pairplot(df1,hue='Category')

# %% [markdown]
# #### Highest Sales is at Office Supplies Category followed by Furniture & Technology Categories

# %% [markdown]
# #### Sub Category

# %%
df1['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(15,12))
df1['Sub-Category'].value_counts().plot.pie(autopct='%1.1f%%').set_title('SUB CATEGORIES')
plt.show()

# %% [markdown]
# #### Highest Sales is for Binders,Papers and Furnishings Whereas Lowest is for Supplies,Machines and Copiers

# %% [markdown]
# #### Region

# %%
df1['Region'].value_counts()
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(10,8))
df1.Region.value_counts().plot.pie(autopct='%.1f%%').set_title("REGION")
plt.show()

# %% [markdown]
# #### Highest Sales Occurs at West & East Regions

# %% [markdown]
# #### State

# %%
df1['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
ps = df.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(figsize=(15,10))
plt.title('SALES & PROFIT ACROSS STATES')
plt.xlabel('States')
plt.ylabel('Sales/Profit')
plt.show()

# %% [markdown]
# #### Highest Sales is at California and New York Sates while Lowest Profit is at Texas and Ohio States

# %% [markdown]
# #### Sales & Profit Per Region

# %%
df1.groupby('Region')['Sales','Profit'].sum().plot.bar()
plt.title('Sale & profit in each region')
plt.legend()
plt.show()

# %% [markdown]
# #### West & East Regions have Better Sales and Profit than Cenatral & south Regions

# %% [markdown]
# #### Sales of each Category Per Region

# %%
df1_segment1=df1[['Category','Region','Sales']]
df1_sgrp1=df1_segment1.groupby(['Category','Region'],as_index=False).mean()
df1_sgrp1
# Out:
#            Category   Region       Sales
# 0         Furniture  Central  340.431654
# 1         Furniture     East  346.683053
# 2         Furniture    South  353.309289
# 3         Furniture     West  357.777059
# 4   Office Supplies  Central  117.659864
# 5   Office Supplies     East  120.147008
# 6   Office Supplies    South  126.282727
# 7   Office Supplies     West  116.881992
# 8        Technology  Central  405.753124
# 9        Technology     East  495.278469
# 10       Technology    South  507.753952
# 11       Technology     West  420.687533

# %%
df1_pivot1=df1_sgrp1.pivot(index='Region',columns='Category')
df1_pivot1
# Out:
#                Sales
# Category   Furniture Office Supplies  Technology
# Region
# Central   340.431654      117.659864  405.753124
# East      346.683053      120.147008  495.278469
# South     353.309289      126.282727  507.753952
# West      357.777059      116.881992  420.687533

# %%
ax = sns.heatmap(df1_pivot1, annot=True,linewidth=.05)

# %% [markdown]
# #### Technology Category has the highest sales (at South Region) & Office Supplies has the least sales (at West Region )

# %% [markdown]
# ####  Profit of each Category Per Region

# %%
df1_segment2=df1[['Category','Region','Profit']]
df1_sgrp2=df1_segment2.groupby(['Category','Region'],as_index=False).mean()
df1_sgrp2
# Out:
#            Category   Region     Profit
# 0         Furniture  Central  -6.054472
# 1         Furniture     East   5.097041
# 2         Furniture    South  20.395199
# 3         Furniture     West  16.286869
# 4   Office Supplies  Central   6.247068
# 5   Office Supplies     East  23.968450
# 6   Office Supplies    South  20.086827
# 7   Office Supplies     West  27.821837
# 8        Technology  Central  80.231981
# 9        Technology     East  88.714084
# 10       Technology    South  68.231506
# 11       Technology     West  73.962687

# %%
df1_pivot2=df1_sgrp2.pivot(index='Region',columns='Category')
df1_pivot2
# Out:
#              Profit
# Category  Furniture Office Supplies Technology
# Region
# Central   -6.054472        6.247068  80.231981
# East       5.097041       23.968450  88.714084
# South     20.395199       20.086827  68.231506
# West      16.286869       27.821837  73.962687

# %%
ax = sns.heatmap(df1_pivot2, annot=True,linewidth=.05)

# %% [markdown]
# #### Technology Category has the highest profit (at East Region) & Furniture has the least profit (at Central Region )

# %% [markdown]
# #### Sales & Profit Per Segment

# %%
df1.groupby('Segment')['Sales','Profit'].sum().plot.bar()
plt.title('Sales & Profit at each Customer Segment')
plt.legend()
plt.show()

# %% [markdown]
# #### Consumer & Corporate Segments have High Sales and Profit than Home Office Segment

# %% [markdown]
# #### Sales of each Category Per Segment

# %%
df1_segment3=df1[['Category','Segment','Sales']]
df1_sgrp3=df1_segment3.groupby(['Category','Segment'],as_index=False).mean()
df1_sgrp3
# Out:
#           Category      Segment       Sales
# 0        Furniture     Consumer  351.312358
# 1        Furniture    Corporate  354.519792
# 2        Furniture  Home Office  337.853293
# 3  Office Supplies     Consumer  116.594082
# 4  Office Supplies    Corporate  127.052466
# 5  Office Supplies  Home Office  115.470271
# 6       Technology     Consumer  427.339534
# 7       Technology    Corporate  444.855810
# 8       Technology  Home Office  535.976658

# %%
df1_pivot3=df1_sgrp3.pivot(index='Segment',columns='Category')
df1_pivot3
# Out:
#                   Sales
# Category      Furniture Office Supplies  Technology
# Segment
# Consumer     351.312358      116.594082  427.339534
# Corporate    354.519792      127.052466  444.855810
# Home Office  337.853293      115.470271  535.976658

# %%
ax = sns.heatmap(df1_pivot3, annot=True,linewidth=.05)

# %% [markdown]
# #### Technology Category has the highest sales (at Home Office Segment) & Home Office Supplies has least sales (at Home office Segment)

# %% [markdown]
# #### Profit of each Category Per Segment

# %%
df1_segment4=df1[['Category','Segment','Profit']]
df1_sgrp4=df1_segment4.groupby(['Category','Segment'],as_index=False).mean()
df1_sgrp4
# Out:
#           Category      Segment     Profit
# 0        Furniture     Consumer   6.255379
# 1        Furniture    Corporate  11.741201
# 2        Furniture  Home Office  10.780602
# 3  Office Supplies     Consumer  18.030016
# 4  Office Supplies    Corporate  22.150505
# 5  Office Supplies  Home Office  24.055566
# 6       Technology     Consumer  74.445646
# 7       Technology    Corporate  79.723823
# 8       Technology  Home Office  89.152458

# %%
df1_pivot4=df1_sgrp4.pivot(index='Segment',columns='Category')
df1_pivot4
# Out:
#                 Profit
# Category     Furniture Office Supplies Technology
# Segment
# Consumer      6.255379       18.030016  74.445646
# Corporate    11.741201       22.150505  79.723823
# Home Office  10.780602       24.055566  89.152458

# %%
ax = sns.heatmap(df1_pivot4, annot=True,linewidth=.05)

# %% [markdown]
# #### Technology Category has the highest profit (at Home Office Segment) & Furniture Category has lowest profit (at Cosumer Segment)

# %% [markdown]
# #### Sales of Sub Category

# %%
df1_segment5=df1[['Sub-Category','Sales']]
df1_sgrp5=df1_segment5.groupby(['Sub-Category'],as_index=False).mean()
df1_sgrp5
# Out:
#    Sub-Category        Sales
# 0   Accessories   215.974604
# 1    Appliances   230.755710
# 2           Art    34.096896
# 3       Binders   133.645972
# 4     Bookcases   503.859633
# 5        Chairs   532.971969
# 6       Copiers  2198.941618
# 7     Envelopes    64.867724
# 8     Fasteners    13.936774
# 9   Furnishings    95.902745
# 10       Labels    34.283504
# 11     Machines  1645.553313
# 12        Paper    57.560075
# 13       Phones   371.211534
# 14      Storage   264.590553
# 15     Supplies   245.650200
# 16       Tables   648.794771

# %% [markdown]
# #### Profit of Sub Category

# %%
df1_segment6=df1[['Sub-Category','Profit']]
df1_sgrp6=df1_segment6.groupby(['Sub-Category'],as_index=False).mean()
df1_sgrp6
# Out:
#    Sub-Category      Profit
# 0   Accessories   54.111788
# 1    Appliances   38.922758
# 2           Art    8.207059
# 3       Binders   19.860710
# 4     Bookcases  -15.230509
# 5        Chairs   43.198582
# 6       Copiers  817.909190
# 7     Envelopes   27.418019
# 8     Fasteners    4.375660
# 9   Furnishings   13.653476
# 10       Labels   15.224193
# 11     Machines   29.432669
# 12        Paper   24.977365
# 13       Phones   50.073938
# 14      Storage   25.152277
# 15     Supplies   -6.258418
# 16       Tables  -55.565771

# %%
ps = df1.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(figsize=(15,10))
plt.title('Profit/Loss and Sales across states')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# #### Phones,Chairs,Storage has highest Sales & Tables,Bookcases,Supllies has least Profit

# %% [markdown]
# #### Sales & Profit of Each Categories

# %%
df1.groupby('Category')['Sales','Profit'].sum().plot.bar()
plt.title('Sale & profit in different categories')
plt.legend(loc=1)
plt.show()

# %% [markdown]
# #### Technology & Furniture has more sales  than Office Supllies but in case of Profit, Furniture has least value

# %%
df1[df1['Category']=='Furniture'].groupby('Sub-Category')['Sales','Profit'].sum().plot.bar()
plt.title('PROFIT & LOSS IN SUBCATEGORIES OF FURNITURE')
plt.legend(loc=1)  #loc=1 to get the lebel on right hand side.
plt.show()

# %% [markdown]
# #### Tables and Bookcases has the highest loss in the Furniture Category

# %%
df1[df1['Category']=='Furniture'].groupby('Sub-Category')['Discount'].mean().plot.bar()
plt.title('DISCOUNT GIVEN IN EACH SUB-CATEGORIES')
plt.legend(loc=0)
plt.show()

# %% [markdown]
# #### Discount provided to Bookcases & Tables are higer than other Sub-Categories in the Furniture Category

# %%
plt.style.use('seaborn')
df1.plot(kind='scatter', figsize= (15,10), x='Sales', y='Profit', c='Discount', s= 20, fontsize= 16, colormap= 'cool')
plt.ylabel('Total profits', fontsize= 16)
plt.title('DEPENDANCY OF PROFIT ON DISCOUNT')
plt.show()

# %%
sns.lineplot(x='Discount',y='Profit',label='Profit',data=df1)
plt.legend()
plt.show()

# %% [markdown]
# #### Less Discount leads to more Profit & Higher Discount leads to Loss of the Product

# %%
def state_data_viewer(states):
    product_data = df.groupby(['State'])
    for state in states:
        data = product_data.get_group(state).groupby(['Category'])
        fig,ax =plt.subplots(1, 3, figsize= (20,4))
        fig.suptitle(state, fontsize=14)
        ax_index =0
        for cat in ['Furniture', 'Office Supplies', 'Technology']:
            cat_data = data.get_group(cat).groupby(['Sub-Category']).sum()
            sns.barplot(x=cat_data.Profit, y= cat_data.index, ax =ax[ax_index])
            ax[ax_index].set_ylabel(cat)
            ax_index+=1
        
        fig.show()

# %%
states = ['Texas','Pennsylvania','Illinois','Ohio','North Carolina','Arizona','Colorado','Tennessee']
state_data_viewer(states)

# %% [markdown]
# #### Out of Least Profit Sates, we could see that Tables and Bookcases from Furnitures, Binders from Office Supplies & Machines from Technology leads to the loss

# %%
df1.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).plot.bar()
plt.show()

# %% [markdown]
# ### Obseravtions

# %% [markdown]
# #### 1)Highest Shipping  Mode is Standard Class following with Second & FIrst Class
# #### 2)Highest Segment is Consumer Segment following with Corporate & Home Office
# #### 3)Highest Sales is at Office Supplies Category followed by Furniture & Technology Categories
# #### 4)Highest Sales is for Binders,Papers and Furnishings Whereas Lowest is for Supplies,Machines and Copiers
# #### 5)Highest Sales Occurs at West & East Regions
# #### 6)Highest Sales is at California and New York Sates while Lowest Profit is at Texas and Ohio States

# %% [markdown]
# #### 7)West & East Regions have Better Sales and Profit than Cenatral & south Regions
# #### 8)Technology Category has the highest sales (at South Region) & Office Supplies has the least sales (at West Region )
# #### 9)Technology Category has the highest profit (at East Region) & Furniture has the least profit (at Central Region )
# #### 10)Consumer & Corporate Segments have High Sales and Profit than Home Office Segment
# #### 11)Technology Category has the highest sales (at Home Office Segment) & Home Office Supplies has least sales (at Home office Segment)
# #### 12)echnology Category has the highest profit (at Home Office Segment) & Furniture Category has lowest profit (at Cosumer Segment)

# %% [markdown]
# #### 13)Phones,Chairs,Storage has highest Sales & Tables,Bookcases,Supllies has least Profit
# #### 14)Technology & Furniture has more sales than Office Supllies but in case of Profit, Furniture has least value
# #### 15)Tables and Bookcases has the highest loss in the Furniture Category
# #### 16)Discount provided to Bookcases & Tables are higer than other Sub-Categories in the Furniture Category
# #### 17)Less Discount leads to more Profit & Higher Discount leads to Loss of the Product
# #### 18)Positive correlation between Sales & Profit whereas Negative correlation Discount & Profit

# %% [markdown]
# #### 19)Out of Least Profit Sates, we could see that Tables and Bookcases from Furnitures, Binders from Office Supplies & Machines from Technology leads to the loss

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ### Weak Areas that should get more attention for Increasing the Profit:

# %% [markdown]
# #### 1)Central & South Regions has less sales as well as Profit
# #### 2)District of Columbia,Maine,North Dakota,West Virginia,Wyoming have least Sales
# #### 3)Texas,Pennsylvania,Ilinios,Ohio are the states that have average Sales but Profit less than expected

# %% [markdown]
# #### 4)Furniture category has the least profit among the Categories
# #### 5)Envelopes,Labels,Fasteners have least Sales
# #### 6)Tables,Bookcases,Supplies have an average Sales but Profit less than expected
# #### 7)Binders from Office Supplies & Machines from Technology has least Profit as well

# %% [markdown]
# #### Furnitures has an average Sales but has lowest profit that's beacause the Discount given to the Produts are High when Comparing with others.
# #### Discount has negative Correlation with Profit, So increase in Discount can lead to Loss
